# %% [markdown]
# # Testing
#  - **@author**: Mario Garcia (mario.garcia@utec.edu.uy)
#  - **@version**: v1.0
#  - **@date**: 2022-08-03
#  - **Output**: Validamos que los semielaborados sean consistentes

# %%
dir_gdrive_base = "/content/drive/MyDrive/ValidacionProductosSatelitales(VPS)/Proyecto Colab/"
# !ls -lhas "$dir_gdrive_base"
# Out:
# total 3.5M
# 4.0K drwx------ 2 root root 4.0K Jul 25 15:07 '02 - DataSource'
# 4.0K drwx------ 2 root root 4.0K Jul 25 22:19 '03 - DataLake'
# 4.0K drwx------ 2 root root 4.0K Jul 27 19:08 '04 - Data Ext'
# 4.0K drwx------ 2 root root 4.0K Jul 27 19:23 '05 - Data Analysis'
# 4.0K drwx------ 2 root root 4.0K Jul 30 06:58 '06 - Merge SBPP Gauge'
# 4.0K drwx------ 2 root root 4.0K Aug  2 21:01 '07 - Report Validation'
# 4.0K drwx------ 2 root root 4.0K Sep 28  2021  backup
#  14K -rw------- 1 root root  14K Mar  5 17:24  Common_1.0.ipynb
# 3.5M -rw------- 1 root root 3.5M Sep 30  2021  Main.ipynb
# 4.0K drwx------ 2 root root 4.0K Oct  8  2021  Stages

# %%
import xarray as xr 
import pandas as pd 
import numpy as np

# %%
# df_xr_raw = xr.open_dataset(file_nc, mask_and_scale=False) # !Important for Null Values
# !Important
# mask = df_xr_raw.precipitation > 0
# df_xr = df_xr_raw.where( mask )

# %%
# dentro del cuadrado de uruguay

file_nc_persiann = dir_gdrive_base+'/03 - DataLake/persiann_daily_2000_2020.nc'
file_nc_chirps = dir_gdrive_base+'/03 - DataLake/chirps_daily_2000_2020.nc'
file_nc_imerg_late = dir_gdrive_base+'/03 - DataLake/imerg_late_daily_2000_2020.nc'
file_nc_imerg_final = dir_gdrive_base+'/03 - DataLake/imerg_final_daily_2000_2020.nc'

file_nc_ute = dir_gdrive_base+'/03 - DataLake/ute_daily_2000_2020.nc'
file_nc_inumet = dir_gdrive_base+'/03 - DataLake/inumet_daily_2000_2020.nc'

# %% [markdown]
# ## Valido que esten implementados los valores nulos y se lean

# %%
# Lectura de los netCDF con tratamiento de mask por parte de xarray
# Esto deberia poner nulos en los valores -598

df_xr_persiann_raw = xr.open_dataset(file_nc_persiann) # , mask_and_scale=True) # !Important for Null Values -598
df_xr_chirps_raw = xr.open_dataset(file_nc_chirps) # , mask_and_scale=True) # !Important for Null Values -598
df_xr_imerg_late_raw = xr.open_dataset(file_nc_imerg_late) # , mask_and_scale=True) # !Important for Null Values -598
df_xr_imerg_final_raw = xr.open_dataset(file_nc_imerg_final) # , mask_and_scale=True) # !Important for Null Values -598

df_xr_ute_raw = xr.open_dataset(file_nc_ute) # , mask_and_scale=True) # !Important for Null Values -598
df_xr_inumet_raw = xr.open_dataset(file_nc_inumet) # , mask_and_scale=True) # !Important for Null Values -598



mask = df_xr_persiann_raw.precipitation >= 0; df_xr_persiann = df_xr_persiann_raw.where( mask )
mask = df_xr_chirps_raw.precipitation >= 0; df_xr_chirps = df_xr_chirps_raw.where( mask )
mask = df_xr_imerg_late_raw.precipitation >= 0; df_xr_imerg_late = df_xr_imerg_late_raw.where( mask )
mask = df_xr_imerg_final_raw.precipitation >= 0; df_xr_imerg_final = df_xr_imerg_final_raw.where( mask )

mask = df_xr_ute_raw.precipitation >= 0; df_xr_ute = df_xr_ute_raw.where( mask )
mask = df_xr_inumet_raw.precipitation >= 0; df_xr_inumet = df_xr_inumet_raw.where( mask )


# df_xr_persiann
persiann_sum = df_xr_persiann['precipitation'].sum().values 
chirps_sum = df_xr_chirps['precipitation'].sum().values 
imerg_late_sum = df_xr_imerg_late['precipitation'].sum().values 
imerg_final_sum = df_xr_imerg_final['precipitation'].sum().values 

ute_sum = df_xr_ute['precipitation'].sum().values 
inumet_sum = df_xr_inumet['precipitation'].sum().values 

persiann_sum, chirps_sum, imerg_late_sum, imerg_final_sum, ute_sum, inumet_sum
# Out:
# (array(3.391253e+08, dtype=float32),
#  array(3.2788918e+08, dtype=float32),
#  array(1.17261064e+08, dtype=float32),
#  array(91807376., dtype=float32),
#  array(3587608., dtype=float32),
#  array(763499.8, dtype=float32))

# %%
# # Lectura de los netCDF SIN tratamiento de mask por parte de xarray
# # Esto deberia traer  los valores -598

# df_xr_persiann = xr.open_dataset(file_nc_persiann) #, mask_and_scale=False) # !Important for Null Values -598
# df_xr_chirps = xr.open_dataset(file_nc_chirps) #, mask_and_scale=False) # !Important for Null Values -598
# df_xr_imerg_late = xr.open_dataset(file_nc_imerg_late) #, mask_and_scale=False) # !Important for Null Values -598
# df_xr_imerg_final = xr.open_dataset(file_nc_imerg_final) #, mask_and_scale=False) # !Important for Null Values -598

# df_xr_ute = xr.open_dataset(file_nc_ute) #, mask_and_scale=False) # !Important for Null Values -598
# df_xr_inumet = xr.open_dataset(file_nc_inumet) #, mask_and_scale=False) # !Important for Null Values -598


# # df_xr_persiann
# persiann_sum = df_xr_persiann['precipitation'].sum().values # 8187118.5
# chirps_sum = df_xr_chirps['precipitation'].sum().values # 8187118.5
# imerg_late_sum = df_xr_imerg_late['precipitation'].sum().values # 8187118.5
# imerg_final_sum = df_xr_imerg_final['precipitation'].sum().values # 8187118.5

# ute_sum = df_xr_ute['precipitation'].sum().values # 8187118.5
# inumet_sum = df_xr_inumet['precipitation'].sum().values # 8187118.5

# persiann_sum, chirps_sum, imerg_late_sum, imerg_final_sum, ute_sum, inumet_sum

# %%
# persiann_sum       (array(8187118.5, dtype=float32),         (array(-6.127845e+08, dtype=float32),  
# chirps_sum          array(3.2788918e+08, dtype=float32),      array(-3.6034145e+09, dtype=float32),  
# imerg_late_sum      array(1.17261064e+08, dtype=float32),     array(1.17261064e+08, dtype=float32),  
# imerg_final_sum     array(91807376., dtype=float32),          array(91807376., dtype=float32),  
# ute_sum             array(3587608., dtype=float32),           array(-8.867253e+10, dtype=float32),  
# inumet_sum          array(763499.8, dtype=float32))           array(-3.4734497e+09, dtype=float32))  

# En todos se ven afectado por los nullos excepto IMERG que pareceria que no tienen valores nulos

# %% [markdown]
# ## Testing de formato de archivos netCDF

# %%
# !sudo apt-get -y install netcdf-bin
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   netcdf-bin
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 189 kB of archives.
# After this operation, 524 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 netcdf-bin amd64 1:4.6.0-2build1 [189 kB]
# Fetched 189 kB in 0s (395 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package netcdf-bin.
# (Reading database ... 155680 files and directories currently installed.)
# Preparing to unpack .../netcdf-bin_1%3a4.6.0-2build1_amd64.deb ...
# Unpacking netcdf-bin (1:4.6.0-2build1) ...
# Setting up netcdf-bin (1:4.6.0-2build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !ncdump -h "$file_nc_persiann"
# !ncdump -h "$file_nc_chirps"
# !ncdump -h "$file_nc_imerg_late"
# !ncdump -h "$file_nc_imerg_final"
# !ncdump -h "$file_nc_ute"
# !ncdump -h "$file_nc_inumet"
# Out:
# netcdf persiann_daily_2000_2020 {
# dimensions:
# 	time = 7611 ;
# 	lat = 124 ;
# 	lon = 135 ;
# variables:
# 	float precipitation(time, lat, lon) ;
# 		precipitation:_FillValue = NaNf ;
# 	float lon(lon) ;
# 		lon:_FillValue = NaNf ;
# 	float lat(lat) ;
# 		lat:_FillValue = NaNf ;
# 	int64 time(time) ;
# 		time:units = "days since 2000-03-01 00:00:00" ;
# 		time:calendar = "proleptic_gregorian" ;
#
# // global attributes:
# 		:Conventions = "CF-1.6" ;
# }
# netcdf chirps_daily_2000_2020 {
# dimensions:
# 	time = 7671 ;
# 	lat = 100 ;
# 	lon = 120 ;
# variables:
# 	float precipitation(time, lat, lon) ;
# 		precipitation:_FillValue = NaNf ;
# 	float lat(lat) ;
# 		lat:_FillValue = NaNf ;
# 	float lon(lon) ;
# 		lon:_FillValue = NaNf ;
# 	int64 time(time) ;
# 		time:units = "days since 2000-01-01 00:00:00" ;
# 		time:calendar = "proleptic_gregorian" ;
#
# // global attributes:
# 		:Conventions = "CF-1.6" ;
# 		:title = "CHIRPS Version 2.0" ;
# 		:history = "created by Climate Hazards Group" ;
# 		:version = "Version 2.0" ;
# 		:date_created = "2015-11-20" ;
# 		:creator_name = "Pete Peterson" ;
# 		:creator_email = "pete@geog.ucsb.edu" ;
# 		:institution = "Climate Hazards Group.  University of California at Santa Barbara" ;
# 		:documentation = "http://pubs.usgs.gov/ds/832/" ;
# 		:reference = "Funk, C.C., Peterson, P.J., Landsfeld, M.F., Pedreros, D.H., Verdin, J.P., Rowland, J.D., Romero, B.E., Husak, G.J., Michaelsen, J.C., and Verdin, A.P., 2014, A quasi-global precipitation time series for drought monitoring: U.S. Geological Survey Data Series 832, 4 p., http://dx.doi.org/110.3133/ds832. " ;
# 		:comments = " time variable denotes the first day of the given day." ;
# 		:acknowledgements = "The Climate Hazards Group InfraRed Precipitation with Stations development process was carried out through U.S. Geological Survey (USGS) cooperative agreement #G09AC000001 \"Monitoring and Forecasting Climate, Water and Land Use for Food Production in the Developing World\" with funding from: U.S. Agency for International Development Office of Food for Peace, award #AID-FFP-P-10-00002 for \"Famine Early Warning Systems Network Support,\" the National Aeronautics and Space Administration Applied Sciences Program, Decisions award #NN10AN26I for \"A Land Data Assimilation System for Famine Early Warning,\" SERVIR award #NNH12AU22I for \"A Long Time-Series Indicator of Agricultural Drought for the Greater Horn of Africa,\" The National Oceanic and Atmospheric Administration award NA11OAR4310151 for \"A Global Standardized Precipitation Index supporting the US Drought Portal and the Famine Early Warning System Network,\" and the USGS Land Change Science Program." ;
# 		:ftp_url = "ftp://chg-ftpout.geog.ucsb.edu/pub/org/chg/products/CHIRPS-latest/" ;
# 		:website = "http://chg.geog.ucsb.edu/data/chirps/index.html" ;
# 		:faq = "http://chg-wiki.geog.ucsb.edu/wiki/CHIRPS_FAQ" ;
# }
# netcdf imerg_late_daily_2000_2020 {
# dimensions:
# 	time = 7519 ;
# 	lon = 60 ;
# 	lat = 50 ;
# variables:
# 	float precipitation(time, lon, lat) ;
# 		precipitation:_FillValue = NaNf ;
# 	float lat(lat) ;
# 		lat:_FillValue = NaNf ;
# 	float lon(lon) ;
# 		lon:_FillValue = NaNf ;
# 	int64 time(time) ;
# 		time:units = "days since 2000-06-01 00:00:00.000000" ;
# 		time:calendar = "julian" ;
#
# // global attributes:
# 		:BeginDate = "2000-06-01" ;
# 		:BeginTime = "00:00:00.000Z" ;
# 		:EndDate = "2000-06-01" ;
# 		:EndTime = "23:59:59.999Z" ;
# 		:FileHeader = "StartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGranuleDateTime=2000-06-01T23:59:59.999Z" ;
# 		:InputPointer = "3B-HHR-L.MS.MRG.3IMERG.20000601-S000000-E002959.0000.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S003000-E005959.0030.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S010000-E012959.0060.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S013000-E015959.0090.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S020000-E022959.0120.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S023000-E025959.0150.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S030000-E032959.0180.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S033000-E035959.0210.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S040000-E042959.0240.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S043000-E045959.0270.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S050000-E052959.0300.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S053000-E055959.0330.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S060000-E062959.0360.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S063000-E065959.0390.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S070000-E072959.0420.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S073000-E075959.0450.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S080000-E082959.0480.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S083000-E085959.0510.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S090000-E092959.0540.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S093000-E095959.0570.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S100000-E102959.0600.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S103000-E105959.0630.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S110000-E112959.0660.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S113000-E115959.0690.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S120000-E122959.0720.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S123000-E125959.0750.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S130000-E132959.0780.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S133000-E135959.0810.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S140000-E142959.0840.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S143000-E145959.0870.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S150000-E152959.0900.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S153000-E155959.0930.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S160000-E162959.0960.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S163000-E165959.0990.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S170000-E172959.1020.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S173000-E175959.1050.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S180000-E182959.1080.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S183000-E185959.1110.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S190000-E192959.1140.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S193000-E195959.1170.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S200000-E202959.1200.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S203000-E205959.1230.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S210000-E212959.1260.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S213000-E215959.1290.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S220000-E222959.1320.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S223000-E225959.1350.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S230000-E232959.1380.V06B.HDF5;3B-HHR-L.MS.MRG.3IMERG.20000601-S233000-E235959.1410.V06B.HDF5" ;
# 		:title = "GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 degree (GPM_3IMERGDL)" ;
# 		:DOI = "10.5067/GPM/IMERGDL/DAY/06" ;
# 		:ProductionTime = "2019-08-07T19:51:27.150Z" ;
# 		:history = "2022-07-26 06:49:56 GMT Hyrax-1.16.3 https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDL.06/2000/06/3B-DAY-L.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1210:1270][549:599],time,lon[1210:1270],lat[549:599]" ;
# }
# netcdf imerg_final_daily_2000_2020 {
# dimensions:
# 	time = 7519 ;
# 	lon = 60 ;
# 	lat = 50 ;
# variables:
# 	float precipitation(time, lon, lat) ;
# 		precipitation:_FillValue = NaNf ;
# 	float lat(lat) ;
# 		lat:_FillValue = NaNf ;
# 	float lon(lon) ;
# 		lon:_FillValue = NaNf ;
# 	int64 time(time) ;
# 		time:units = "days since 2000-06-01 00:00:00.000000" ;
# 		time:calendar = "julian" ;
#
# // global attributes:
# 		:BeginDate = "2000-06-01" ;
# 		:BeginTime = "00:00:00.000Z" ;
# 		:EndDate = "2000-06-01" ;
# 		:EndTime = "23:59:59.999Z" ;
# 		:FileHeader = "StartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGranuleDateTime=2000-06-01T23:59:59.999Z" ;
# 		:InputPointer = "3B-HHR.MS.MRG.3IMERG.20000601-S000000-E002959.0000.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S003000-E005959.0030.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S010000-E012959.0060.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S013000-E015959.0090.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S020000-E022959.0120.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S023000-E025959.0150.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S030000-E032959.0180.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S033000-E035959.0210.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S040000-E042959.0240.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S043000-E045959.0270.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S050000-E052959.0300.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S053000-E055959.0330.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S060000-E062959.0360.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S063000-E065959.0390.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S070000-E072959.0420.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S073000-E075959.0450.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S080000-E082959.0480.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S083000-E085959.0510.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S090000-E092959.0540.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S093000-E095959.0570.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S100000-E102959.0600.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S103000-E105959.0630.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S110000-E112959.0660.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S113000-E115959.0690.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S120000-E122959.0720.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S123000-E125959.0750.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S130000-E132959.0780.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S133000-E135959.0810.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S140000-E142959.0840.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S143000-E145959.0870.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S150000-E152959.0900.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S153000-E155959.0930.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S160000-E162959.0960.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S163000-E165959.0990.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S170000-E172959.1020.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S173000-E175959.1050.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S180000-E182959.1080.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S183000-E185959.1110.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S190000-E192959.1140.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S193000-E195959.1170.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S200000-E202959.1200.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S203000-E205959.1230.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S210000-E212959.1260.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S213000-E215959.1290.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S220000-E222959.1320.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S223000-E225959.1350.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S230000-E232959.1380.V06B.HDF5;3B-HHR.MS.MRG.3IMERG.20000601-S233000-E235959.1410.V06B.HDF5" ;
# 		:title = "GPM IMERG Final Precipitation L3 1 day 0.1 degree x 0.1 degree (GPM_3IMERGDF)" ;
# 		:DOI = "10.5067/GPM/IMERGDF/DAY/06" ;
# 		:ProductionTime = "2019-06-18T20:51:50.167Z" ;
# 		:history = "2022-07-26 07:16:09 GMT Hyrax-1.16.3 https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGDF.06/2000/06/3B-DAY.MS.MRG.3IMERG.20000601-S000000-E235959.V06.nc4.nc4?precipitationCal[0:0][1210:1270][549:599],time,lon[1210:1270],lat[549:599]" ;
# }
# netcdf ute_daily_2000_2020 {
# dimensions:
# 	time = 7671 ;
# 	lat = 139 ;
# 	lon = 140 ;
# variables:
# 	float precipitation(time, lat, lon) ;
# 		precipitation:_FillValue = NaNf ;
# 	int64 time(time) ;
# 		time:units = "days since 2000-01-01 00:00:00" ;
# 		time:calendar = "proleptic_gregorian" ;
# 	float lat(lat) ;
# 		lat:_FillValue = NaNf ;
# 	float lon(lon) ;
# 		lon:_FillValue = NaNf ;
# }
# netcdf inumet_daily_2000_2020 {
# dimensions:
# 	time = 7672 ;
# 	lat = 28 ;
# 	lon = 28 ;
# variables:
# 	float precipitation(time, lat, lon) ;
# 		precipitation:_FillValue = NaNf ;
# 	int64 time(time) ;
# 		time:units = "days since 2000-01-01 00:00:00" ;
# 		time:calendar = "proleptic_gregorian" ;
# 	float lat(lat) ;
# 		lat:_FillValue = NaNf ;
# 	float lon(lon) ;
# 		lon:_FillValue = NaNf ;
# }

# %%
# los archivos estan seteados todos con precipitation:_FillValue = -598.f ;

# Nota: en los IMERG el time esta en time:calendar = "julian"

# %%
df_xr_persiann_raw
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 7611, lat: 124, lon: 135)
# Coordinates:
#   * lon            (lon) float32 -58.44 -58.4 -58.36 ... -53.16 -53.12 -53.08
#   * lat            (lat) float32 -30.04 -30.08 -30.12 ... -34.88 -34.92 -34.96
#   * time           (time) datetime64[ns] 2000-03-01 2000-03-02 ... 2020-12-31
# Data variables:
#     precipitation  (time, lat, lon) float32 -598.0 -598.0 ... -598.0 -598.0
# Attributes:
#     Conventions:  CF-1.6

# %%
print(df_xr_persiann_raw)
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 7611, lat: 124, lon: 135)
# Coordinates:
#   * lon            (lon) float32 -58.44 -58.4 -58.36 ... -53.16 -53.12 -53.08
#   * lat            (lat) float32 -30.04 -30.08 -30.12 ... -34.88 -34.92 -34.96
#   * time           (time) datetime64[ns] 2000-03-01 2000-03-02 ... 2020-12-31
# Data variables:
#     precipitation  (time, lat, lon) float32 -598.0 -598.0 ... -598.0 -598.0
# Attributes:
#     Conventions:  CF-1.6
