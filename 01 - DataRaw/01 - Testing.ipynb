# %%
dir_google_drive = "/content/drive/MyDrive/ValidacionProductosSatelitales(VPS)/Proyecto Colab/01 - DataRaw"
dir_google_drive_db = dir_google_drive+"/datasets/master"

# %%
# !ls -lhas "$dir_google_drive"/../
# Out:
# total 3.6M
# 4.0K drwx------ 3 root root 4.0K Aug 10 16:17 '01 - DataRaw'
# 4.0K drwx------ 2 root root 4.0K Jul 25 15:07 '02 - DataSource'
# 4.0K drwx------ 2 root root 4.0K Jul 25 22:19 '03 - DataLake'
# 4.0K drwx------ 2 root root 4.0K Jul 27 19:08 '04 - Data Ext'
# 4.0K drwx------ 2 root root 4.0K Jul 27 19:23 '05 - Data Analysis'
# 4.0K drwx------ 2 root root 4.0K Jul 30 06:58 '06 - Merge SBPP Gauge'
# 4.0K drwx------ 2 root root 4.0K Aug 12 01:05 '07 - Reports'
# 4.0K drwx------ 2 root root 4.0K Aug 12 03:24 '08 - Dashboard'
# 4.0K drwx------ 2 root root 4.0K Sep 28  2021  backup
#  14K -rw------- 1 root root  14K Mar  5 17:24  Common_1.0.ipynb
# 3.5M -rw------- 1 root root 3.5M Sep 30  2021  Main.ipynb
# 4.0K drwx------ 2 root root 4.0K Oct  8  2021  Stages

# %%
# datos crudos provenientes de las fuentes

# Satellite
file_master_data_raw_imerg_final      = dir_google_drive_db+"/master_data_raw_imerg_final.tar.gz"
file_master_data_raw_imerg_late       = dir_google_drive_db+"/master_data_raw_imerg_late.tar.gz"
file_master_data_raw_persiann         = dir_google_drive_db+"/master_data_raw_persiann.zip"

# Gauges
file_master_data_raw_inumet_2000_2020 = dir_google_drive_db+"/master_data_raw_inumet_2000_2020.zip"
file_master_data_raw_ute_2000_2020    = dir_google_drive_db+"/master_data_raw_ute_2000_2020.zip"

# Geo data
file_master_geodata_raw_inumet        = dir_google_drive_db+"/master_geodata_raw_inumet.json"
file_master_geodata_raw_ute           = dir_google_drive_db+"/master_geodata_raw_ute.csv"

# %%
# !cp "$file_master_data_raw_persiann" . 
# !cp "$file_master_data_raw_inumet_2000_2020" .
# !cp "$file_master_data_raw_ute_2000_2020" .

# %%
# !unzip  master_data_raw_persiann.zip
# !unzip  master_data_raw_inumet_2000_2020.zip
# !unzip  master_data_raw_ute_2000_2020.zip

# %%
# !cp "$file_master_data_raw_imerg_final" .
# !cp "$file_master_data_raw_imerg_late" .

# %%
# !tar -xvzf master_data_raw_imerg_final.tar.gz
# !tar -xvzf master_data_raw_imerg_late.tar.gz

# %%
# !ls /content/data_late | wc -l
# Out:
# 7523

# %%
import pandas as pd
