# %%
dir_google_drive = "/content/drive/MyDrive/ValidacionProductosSatelitales(VPS)/Proyecto Colab/01 - DataRaw"

# datos crudos provenientes de las fuentes
file_ute = dir_google_drive+"/data_raw_ute_2000_2020.zip"
file_inumet = dir_google_drive+"/data_raw_inumet_2000_2020.zip"

# %%
import pandas as pd

# %%
# !rm -rf Precipitaciones data

# %%
# !cp "$file_ute" /content
# !cp "$file_inumet" /content

# %%
# !unzip "/content/data_raw_ute_2000_2020.zip"
# !unzip "/content/data_raw_inumet_2000_2020.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/2005-Junio-2005-Diciembre-PALMAR-SRIOYI-PINTOS-paso.txt
#   inflating: data/2004-Enero-2004-Junio-GTERRA-STACUA-CCARDO-paso.txt
#   inflating: data/2018-Junio-2018-Diciembre-GTERRA-STACUA-LUJAN-paso.txt
#   inflating: data/2016-Enero-2016-Junio-BRNEGRO-SDERURUG-EJIDO-paso.txt
#   inflating: data/2004-Enero-2004-Junio-GTERRA-SDTERRA-EMBONETE-paso.txt
#   inflating: data/2011-Enero-2011-Junio-GTERRA-STACUA-MCORRAL-paso.txt
#   inflating: data/2016-Junio-2016-Diciembre-GTERRA-SARNEGRO-PPEREI-paso.txt
#   inflating: data/2003-Enero-2003-Junio-GTERRA-SDTERRA-LPALOMA-paso.txt
#   inflating: data/2010-Junio-2010-Diciembre-BAYGO-SSALSI-EMQUADRO-paso.txt
#   inflating: data/2019-Enero-2019-Junio-GTERRA-SARNEGRO-PMAZAN-paso.txt
#   inflating: data/2001-Junio-2001-Diciembre-GTERRA-STACUA-LHILERA-paso.txt
#   inflating: data/2016-Junio-2016-Diciembre-GTERRA-STACUA-CSAUCES-paso.txt
# ...

# %%
# !ls Precipitaciones
# Out:
# '1622830248819-25 de Agosto 2000-2021.xlsx'
# '1622830248826-Capilla del Sauce 2000-2021.xlsx'
# '1622830248830-Cerro Colorado 2000-2021.xlsx'
# '1622830248834-Colonia Miguelete 2000-2021.xlsx'
# '1622830248838-Conchillas 2000-2021.xlsx'
# '1622830248842-E.Met.Artigas 2000-2021.xlsx'
# '1622830248863-E.Met.Carrasco 2000-2021.xlsx'
# '1622830248867-E.Met.Colonia 2000-2021.xlsx'
# '1622830248871-E.Met.Durazno 2000-2021.xlsx'
# '1622830248875-E.Met.Florida 2000-2021.xlsx'
# '1622830248879-E.Met.Melilla 2000-2021.xlsx'
# '1622830248883-E.Met.Melo 2000-2021.xlsx'
# '1622830248887-E.Met.Mercedes 2000-2021.xlsx'
# '1622830248891-E.Met.Paysandu 2000-2021.xlsx'
# '1622830248895-E.Met.Prado 2000-2021.xlsx'
# '1622830248898-E.Met.Punta del Este 2000-2021.xlsx'
# '1622830248902-E.Met.Rivera 2000-2021.xlsx'
# '1622830248906-E.Met.Rocha 2000-2021.xlsx'
# '1622830248910-E.Met.Salto 2000-2021.xlsx'
# '1622830248914-E.Met.San Jose 2000-2021.xlsx'
# '1622830248918-E.Met.Treinta y Tres 2000-2021.xlsx'
# ...
